# %%
# !python extract_plddt_npy.py \
    --input_path /home/workhorse/ProteinMPNN_KL/KL_pipeline_scripts/test \
    --output_dir /home/workhorse/ProteinMPNN_KL/KL_pipeline_scripts/testresults \
    --plddt_range 0-80 \
    --log_dir logs

# %%
import numpy as np

results = np.load("/home/workhorse/ProteinMPNN_KL/KL_pipeline_scripts/testresults/plddt_positions.npy", allow_pickle=True).item()

for pdb_name, info in results.items():
    print(f"{pdb_name}:")
    print(f"Residue positions in range: {info['positions']}")
    print(f"All chains identical? {info['all_chains_same']}")
    print()
# Out:
# realign_test.pdb:
# ...

# %%
# !python3 position_writer.py --fasta /Users/marcohuang/Desktop/Keasling_Lab/MSAReader/Inputs/combined_test_2.fasta --output /Users/marcohuang/Desktop/Keasling_Lab/ProteinMPNN_KL/KL_pipeline_scripts/testresults --protein_of_interest /Users/marcohuang/Desktop/Keasling_Lab/MSAReader/Inputs/test_WT.fasta --threshold 50
# Out:
# usage: position_writer.py [-h] --fasta FASTA [FASTA ...] --output OUTPUT
# position_writer.py: error: unrecognized arguments: --protein_of_interest /Users/marcohuang/Desktop/Keasling_Lab/MSAReader/Inputs/test_WT.fasta --threshold 50
